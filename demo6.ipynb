# %%
# !pip install wfdb
# !pip install neurokit2
# !pip install pandas numpy matplotlib
# Out:
# Requirement already satisfied: wfdb in c:\users\estya\anaconda3\lib\site-packages (4.3.0)
# Requirement already satisfied: aiohttp>=3.10.11 in c:\users\estya\anaconda3\lib\site-packages (from wfdb) (3.12.13)
# Requirement already satisfied: fsspec>=2023.10.0 in c:\users\estya\anaconda3\lib\site-packages (from wfdb) (2024.6.1)
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\estya\anaconda3\lib\site-packages (from wfdb) (3.9.2)
# Requirement already satisfied: numpy>=1.26.4 in c:\users\estya\anaconda3\lib\site-packages (from wfdb) (1.26.4)
# Requirement already satisfied: pandas>=2.2.3 in c:\users\estya\anaconda3\lib\site-packages (from wfdb) (2.3.1)
# Requirement already satisfied: requests>=2.8.1 in c:\users\estya\anaconda3\lib\site-packages (from wfdb) (2.32.3)
# Requirement already satisfied: scipy>=1.13.0 in c:\users\estya\anaconda3\lib\site-packages (from wfdb) (1.13.1)
# Requirement already satisfied: soundfile>=0.10.0 in c:\users\estya\anaconda3\lib\site-packages (from wfdb) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\estya\anaconda3\lib\site-packages (from aiohttp>=3.10.11->wfdb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\estya\anaconda3\lib\site-packages (from aiohttp>=3.10.11->wfdb) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\estya\anaconda3\lib\site-packages (from aiohttp>=3.10.11->wfdb) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\estya\anaconda3\lib\site-packages (from aiohttp>=3.10.11->wfdb) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\estya\anaconda3\lib\site-packages (from aiohttp>=3.10.11->wfdb) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\estya\anaconda3\lib\site-packages (from aiohttp>=3.10.11->wfdb) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\estya\anaconda3\lib\site-packages (from aiohttp>=3.10.11->wfdb) (1.20.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.2.2->wfdb) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.2.2->wfdb) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.2.2->wfdb) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.2.2->wfdb) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.2.2->wfdb) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.2.2->wfdb) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.2.2->wfdb) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.2.2->wfdb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\estya\anaconda3\lib\site-packages (from pandas>=2.2.3->wfdb) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\estya\anaconda3\lib\site-packages (from pandas>=2.2.3->wfdb) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\estya\anaconda3\lib\site-packages (from requests>=2.8.1->wfdb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\estya\anaconda3\lib\site-packages (from requests>=2.8.1->wfdb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\estya\anaconda3\lib\site-packages (from requests>=2.8.1->wfdb) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\estya\anaconda3\lib\site-packages (from requests>=2.8.1->wfdb) (2025.4.26)
# Requirement already satisfied: cffi>=1.0 in c:\users\estya\anaconda3\lib\site-packages (from soundfile>=0.10.0->wfdb) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\estya\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\estya\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.16.0)
# Requirement already satisfied: neurokit2 in c:\users\estya\anaconda3\lib\site-packages (0.2.12)
# Requirement already satisfied: requests in c:\users\estya\anaconda3\lib\site-packages (from neurokit2) (2.32.3)
# Requirement already satisfied: numpy in c:\users\estya\anaconda3\lib\site-packages (from neurokit2) (1.26.4)
# Requirement already satisfied: pandas in c:\users\estya\anaconda3\lib\site-packages (from neurokit2) (2.3.1)
# Requirement already satisfied: scipy in c:\users\estya\anaconda3\lib\site-packages (from neurokit2) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\estya\anaconda3\lib\site-packages (from neurokit2) (1.5.1)
# Requirement already satisfied: matplotlib>=3.5.0 in c:\users\estya\anaconda3\lib\site-packages (from neurokit2) (3.9.2)
# Requirement already satisfied: PyWavelets>=1.4.0 in c:\users\estya\anaconda3\lib\site-packages (from neurokit2) (1.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.5.0->neurokit2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.5.0->neurokit2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.5.0->neurokit2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.5.0->neurokit2) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.5.0->neurokit2) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.5.0->neurokit2) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.5.0->neurokit2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib>=3.5.0->neurokit2) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\estya\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->neurokit2) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\estya\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->neurokit2) (3.5.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\estya\anaconda3\lib\site-packages (from pandas->neurokit2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\estya\anaconda3\lib\site-packages (from pandas->neurokit2) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\estya\anaconda3\lib\site-packages (from requests->neurokit2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\estya\anaconda3\lib\site-packages (from requests->neurokit2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\estya\anaconda3\lib\site-packages (from requests->neurokit2) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\estya\anaconda3\lib\site-packages (from requests->neurokit2) (2025.4.26)
# Requirement already satisfied: six>=1.5 in c:\users\estya\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->neurokit2) (1.16.0)
# Requirement already satisfied: pandas in c:\users\estya\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy in c:\users\estya\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\estya\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\estya\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\estya\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\estya\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\estya\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\estya\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import wfdb
import os

# Path to your dataset folder
data_folder = "Dataset/ptbxl"

# Load the metadata
df = pd.read_csv(os.path.join(data_folder, "ptbxl_database.csv"))

# Choose a sample record (100Hz version is easier to process)
sample_path = df.loc[0, 'filename_lr']  # low resolution path
record_path = os.path.join(data_folder, sample_path)

# Load the ECG signal and metadata using wfdb
signal, info = wfdb.rdsamp(record_path)

print("Signal shape:", signal.shape)  # (1000, 12) → 10 seconds, 12 leads
# Out:
# Signal shape: (1000, 12)

# %%
import neurokit2 as nk

# Choose Lead II for simplicity
ecg_lead = signal[:, 1]

# Clean the ECG signal (NeuroKit2 uses a bandpass filter internally)
ecg_cleaned = nk.ecg_clean(ecg_lead, sampling_rate=100)

# %%
# Detect R-peaks
peaks, info = nk.ecg_peaks(ecg_cleaned, sampling_rate=100)

# R-peaks indices
r_peaks = info["ECG_R_Peaks"]

print("R-peak indices:", r_peaks)
print("Number of R-peaks detected:", len(r_peaks))
# Out:
# R-peak indices: [115 208 300 393 487 583 679 773 864 961]
# Number of R-peaks detected: 10

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
plt.plot(ecg_cleaned, label='Cleaned ECG - Lead II')
plt.plot(r_peaks, ecg_cleaned[r_peaks], 'ro', label='R-peaks')
plt.title("R-Peak Detection on ECG Signal")
plt.xlabel("Sample")
plt.ylabel("Amplitude")
plt.legend()
plt.grid(True)
plt.show()

# %%
all_r_peaks = []

for i in range(5):  # example: first 5 records
    sample_path = df.loc[i, 'filename_lr']
    record_path = os.path.join(data_folder, sample_path)
    signal, _ = wfdb.rdsamp(record_path)
    ecg_cleaned = nk.ecg_clean(signal[:, 1], sampling_rate=100)  # Lead II
    _, peak_info = nk.ecg_peaks(ecg_cleaned, sampling_rate=100)
    r_peaks = peak_info["ECG_R_Peaks"]
    
    all_r_peaks.append({
        "ecg_id": df.loc[i, 'ecg_id'],
        "patient_id": df.loc[i, 'patient_id'],
        "num_r_peaks": len(r_peaks),
        "r_peak_indices": r_peaks
    })

# Convert to DataFrame
r_peaks_df = pd.DataFrame(all_r_peaks)
print(r_peaks_df.head())
# Out:
#    ecg_id  patient_id  num_r_peaks  \
# 0       1     15709.0           10
# 1       2     13243.0            7
# 2       3     20372.0           10
# 3       4     17014.0           12
# 4       5     17448.0           11
#
#                                       r_peak_indices
# 0  [115, 208, 300, 393, 487, 583, 679, 773, 864, ...
# 1                [100, 231, 368, 502, 627, 747, 863]
# 2  [104, 202, 298, 394, 485, 577, 670, 764, 857, ...
# 3  [108, 191, 279, 364, 446, 522, 601, 680, 762, ...
# 4  [33, 123, 219, 313, 399, 482, 571, 669, 764, 8...
